# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-5",
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": "What image about?",
                },
                {
                    "type": "input_image",
                    "image_url": "https://api.nga.gov/iiif/a2e6da57-3cd1-4235-b20e-95dcaefed6c8/full/!800,800/0/default.jpg"
                }
            ]
        }
    ]
)

print(response.output_text)
# Out:
# It’s a painted portrait of a young girl sitting in a curved wooden chair. She wears a red-and-blue striped top with gold buttons and a blue skirt with orange dots, and she holds a small bunch of flowers. The background is a flat pale teal, and the brushstrokes are bold and textured.
