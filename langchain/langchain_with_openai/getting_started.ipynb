# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGSMITH_API_KEY"]=os.getenv("LANGSMITH_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGSMITH_PROJECT"]=os.getenv("LANGSMITH_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x00000121D191CB50> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000121D2DFD050> root_client=<openai.OpenAI object at 0x00000121D191C710> root_async_client=<openai.AsyncOpenAI object at 0x00000121D2DFCDD0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence algorithms that are designed to generate new data that is similar to a given set of input data. The term is often associated with models that can create text, images, audio, video, and other data types by learning patterns from the training data. \n\nA key component of generative AI is its ability to produce novel outputs while retaining the statistical properties of the training data. Some of the most well-known techniques in this area include:\n\n1. **Generative Adversarial Networks (GANs)**: This approach consists of two neural networks, a generator and a discriminator, that work against each other. The generator creates new data instances, and the discriminator evaluates them for authenticity, pushing the generator to improve.\n\n2. **Variational Autoencoders (VAEs)**: These models use encoders to compress data into a latent space and decoders to reconstruct the data, allowing them to generate new, similar data by sampling from the latent space.\n\n3. **Transformers and Large Language Models (LLMs)**: These models, often based on attention mechanisms, can generate human-like text by predicting the next word in a sentence, making them capable of writing essays, coding, and carrying out conversations.\n\nGenerative AI has numerous applications, including content creation, data augmentation, art generation, drug discovery, and more. While it shows remarkable potential, it also poses challenges related to ethics, privacy, and security.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 292, 'prompt_tokens': 13, 'total_tokens': 305, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_1ceab21c9a', 'id': 'chatcmpl-DWyi4QGZMLeLm5HJkFHhm1S0Vo3le', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019daeaf-9006-74f3-9979-2a222d2c7e4b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 292, 'total_tokens': 305, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content="Langsmith is a service provided by LangChain, designed to assist developers in building, evaluating, and monitoring applications that use language models. It integrates with LangChain's framework to offer developers tools for tracing, visualizing, and understanding how their applications interact with language models. Key features of Langsmith include debugging capabilities, tools for evaluating model output quality, and the ability to generate reports and feedback on application performance. This makes it especially useful for developers who want to ensure the reliability and efficiency of their language model applications." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 33, 'total_tokens': 136, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2608ccf94f', 'id': 'chatcmpl-DWyi9EEpDsNTawdgq5dIZsJfPyZqB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019daeaf-a72a-7ac2-82c8-ffd080af6611-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 103, 'total_tokens': 136, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a suite of tools offered by Langchain, designed to assist developers in building, deploying, and monitoring applications that leverage Large Language Models (LLMs) and AI chains. It provides features that enhance the development lifecycle of AI applications, including the ability to track and analyze how these models perform in real-world scenarios. Key tools within Langsmith include debugging utilities, performance monitoring, and user feedback integration, which together create a comprehensive environment for optimizing AI applications built using Langchain.
