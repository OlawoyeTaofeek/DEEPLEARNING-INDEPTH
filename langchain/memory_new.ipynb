# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.output_parsers import JsonOutputParser
from dotenv import load_dotenv, find_dotenv
import os

load_dotenv(find_dotenv())

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
model = ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key, temperature=0.0)
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001C0B1597F50>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C0B1646F10>, model_name='llama-3.3-70b-versatile', temperature=1e-08, model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
model.invoke([HumanMessage(content="What is the capital of France?")])
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.012130038, 'completion_tokens_details': None, 'prompt_time': 0.002211113, 'prompt_tokens_details': None, 'queue_time': 0.051816477, 'total_time': 0.014341151}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-bd78-7bd1-9fd4-c5617f48ab2c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50})

# %%
model.invoke(
    [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content="What is the capital of France?"),
        AIMessage(content="The capital of France is Paris."),
        HumanMessage(content="What is the population of Paris?")
    ]
)
# Out:
# AIMessage(content='The population of Paris is approximately 2.1 million people within the city limits. However, the larger metropolitan area of Paris, also known as the Île-de-France region, has a population of around 12.2 million people, making it one of the most populous urban areas in Europe.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 72, 'total_tokens': 134, 'completion_time': 0.134909482, 'completion_tokens_details': None, 'prompt_time': 0.003725409, 'prompt_tokens_details': None, 'queue_time': 0.041834, 'total_time': 0.138634891}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c01d-7610-bbca-69c0e4185d54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 62, 'total_tokens': 134})

# %%
model.invoke(
    [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content="Hi, My name is Olawoye Taofeek, I am a senior Data Engineer / Ai Engineer with 10 years of experience."),
        AIMessage(content="Hello Olawoye Taofeek, it's nice to meet you! As a senior Data Engineer and AI Engineer with 10 years of experience, you must have a wealth of knowledge in the field. How can I assist you today?"),
        HumanMessage(content="Hey whats my name and how many years of experience do I have?")
    ]
)
# Out:
# AIMessage(content='Your name is Olawoye Taofeek, and you have 10 years of experience as a senior Data Engineer/AI Engineer.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 145, 'total_tokens': 175, 'completion_time': 0.060191743, 'completion_tokens_details': None, 'prompt_time': 0.00696224, 'prompt_tokens_details': None, 'queue_time': 0.041195441, 'total_time': 0.067153983}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c14d-75c3-96b5-a8eabe193965-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 145, 'output_tokens': 30, 'total_tokens': 175})

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "Hi, My name is {name}, I am a senior Data Engineer / AI Engineer with {years} years of experience."),
    ("ai", "Hello {name}, it's nice to meet you! As a senior Data Engineer and AI Engineer with {years} years of experience, you must have a wealth of knowledge in the field. How can I assist you today?"),
    ("human", "Hey whats my name and how many years of experience do I have?")
])

# %%
messages = prompt.format_messages(
    name="Olawoye Taofeek",
    years=10
)

# %%
response = model.invoke(messages)
print(response.content)
# Out:
# Your name is Olawoye Taofeek, and you have 10 years of experience as a senior Data Engineer / AI Engineer.

# %% [markdown]
# ```python
# from langchain_community.chat_message_histories import ChatMessageHistory
# ```
# - This is an actual working “chat memory container”
# - The actual class that stores the chat messages
#
# Internally
# ```python
# self.messages = []
# # And inside
# [
#     HumanMessage(...),
#     AIMessage(...),
#     HumanMessage(...),
# ]
# ```
# it provides methods like
# ```python
# add_user_message("Hi")
# add_ai_message("Hello")
# get_messages()
# clear()
# ```
# > `ChatMessageHistory` = a list that stores conversation messages

# %% [markdown]
# ```python
# from langchain_core.chat_history import BaseChatMessageHistory
# ```
# - An abstract base class: “All memory classes must follow this structure”
# - It defines HOW memory should behave, not HOW it is implemented
# - More like this:
# ```python
# class BaseChatMessageHistory:
#     def add_user_message(self, message): ...
#     def add_ai_message(self, message): ...
#     def clear(self): ...
# ```
# **LangChain wants flexibility:**
#
# - You can use:
#   - ChatMessageHistory (in-memory)
#   - RedisChatMessageHistory
#   - Database memory
#   - Custom memory
#
# - 👉 As long as they behave the same way.
# - So when you call the function beloow, the return is any valid memroy object
# ```python
# def get_session_history(...) -> BaseChatMessageHistory
# ```

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store = {}

def get_session_history(session_id: str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

with_message_history = RunnableWithMessageHistory(model, get_session_history)

config={
    "configurable": {"session_id": "chat1"}
}

with_message_history.invoke(
    [HumanMessage(content="Hi, my name is Taofeek, and I am a Data Engineer")],
    config=config
)
# Out:
# AIMessage(content='Nice to meet you, Taofeek. As a Data Engineer, you must be working on designing, building, and maintaining large-scale data systems, ensuring the flow of data is smooth and efficient. What specific areas of data engineering interest you the most, such as data warehousing, ETL, data pipelines, or perhaps working with big data technologies like Hadoop or Spark?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 51, 'total_tokens': 129, 'completion_time': 0.25518856, 'completion_tokens_details': None, 'prompt_time': 0.002728131, 'prompt_tokens_details': None, 'queue_time': 0.041930018, 'total_time': 0.257916691}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c37b-7662-b1ad-7acbb9a47ccb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 78, 'total_tokens': 129})

# %%
config={
    "configurable": {"session_id": "chat1"}
}

with_message_history.invoke(
    [HumanMessage(content="What's my name?")],
    config=config
)
# Out:
# AIMessage(content='Your name is Taofeek.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 143, 'total_tokens': 152, 'completion_time': 0.025470131, 'completion_tokens_details': None, 'prompt_time': 0.007518528, 'prompt_tokens_details': None, 'queue_time': 0.042096127, 'total_time': 0.032988659}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c524-7592-9afd-8590de879e1a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 143, 'output_tokens': 9, 'total_tokens': 152})

# %%
history = ChatMessageHistory()
print(history)

# %% [markdown]
# 1. Storage (ChatMessageHistory)
# 2. Interface (BaseChatMessageHistory)
# 3. Orchestration (RunnableWithMessageHistory)

# %%
with_message_history.invoke(
    [HumanMessage(content="Whats the capital of France")],
    config={
        "configurable": {"session_id": "chat2"}
    }
)
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 40, 'total_tokens': 48, 'completion_time': 0.009201861, 'completion_tokens_details': None, 'prompt_time': 0.004811686, 'prompt_tokens_details': None, 'queue_time': 0.040976744, 'total_time': 0.014013547}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c604-7800-bd9f-48c7557bed35-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 8, 'total_tokens': 48})

# %%
with_message_history.invoke(
    [HumanMessage(content="And how big is it, also what year was it founded")],
    config={
        "configurable": {"session_id": "chat2"}
    }
)
# Out:
# AIMessage(content="The city of Paris covers an area of approximately 1,054 square kilometers (407 square miles). \n\nAs for the founding year, Paris has a long and complex history. The city was originally founded by the Celtic tribe known as the Parisii in the 3rd century BC, around 259 BC. The Romans later conquered the city in 52 BC and renamed it Lutetia. Over time, the city evolved and grew, with the modern city of Paris emerging in the Middle Ages. So, while it's difficult to pinpoint an exact founding year, 259 BC is often cited as the approximate date when the first settlement was established.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 69, 'total_tokens': 201, 'completion_time': 0.410386144, 'completion_tokens_details': None, 'prompt_time': 0.003711381, 'prompt_tokens_details': None, 'queue_time': 0.040829124, 'total_time': 0.414097525}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58c-c6b4-7aa2-83a2-b1fc06dc7dd9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 69, 'output_tokens': 132, 'total_tokens': 201})

# %%
from typing import Optional
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
store = {}

def get_by_session_id(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

# %%
prompt = ChatPromptTemplate.from_messages(
            [
                ("system", "You're an assistant who's good at {ability}"),
                MessagesPlaceholder(variable_name="history"),
                ("human", "{question}"),
            ]
        )

chain = prompt | ChatGroq(model="llama-3.3-70b-versatile", groq_api_key=groq_api_key, temperature=0.0)

chain_with_history = RunnableWithMessageHistory(
        chain,
            # Uses the get_by_session_id function defined in the example
            # above.
        get_by_session_id,
        input_messages_key="question",
        history_messages_key="history",
        )

print(
    chain_with_history.invoke(  
        {"ability": "math", "question": "What does cosine mean?"},
        config={"configurable": {"session_id": "foo"}},
    )
)

        # Uses the store defined in the example above.
print(store)  

print(
chain_with_history.invoke(  
        {"ability": "math", "question": "What's its inverse"},
            config={"configurable": {"session_id": "foo"}},
        )
    )

print(store)
# Out:
# content="In mathematics, the cosine of an angle is a trigonometric function that describes the ratio of the length of the adjacent side to the length of the hypotenuse in a right-angled triangle.\n\nTo break it down:\n\n* The adjacent side is the side next to the angle you're interested in.\n* The hypotenuse is the longest side of the triangle, opposite the right angle (90-degree angle).\n\nThe cosine of an angle (usually denoted as cos(θ)) is calculated as:\n\ncos(θ) = adjacent side / hypotenuse\n\nFor example, if you have a right-angled triangle with an angle θ, and the adjacent side is 3 units long and the hypotenuse is 5 units long, the cosine of θ would be:\n\ncos(θ) = 3 / 5 = 0.6\n\nThe cosine function is often used in various mathematical and real-world applications, such as:\n\n* Navigation and surveying\n* Physics and engineering\n* Computer graphics and game development\n* Signal processing and analysis\n\nThe cosine function has a range of -1 to 1, and it's a fundamental concept in trigonometry and mathematics." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 240, 'prompt_tokens': 49, 'total_tokens': 289, 'completion_time': 0.551828135, 'completion_tokens_details': None, 'prompt_time': 0.002221162, 'prompt_tokens_details': None, 'queue_time': 0.042010083, 'total_time': 0.554049297}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019da58d-361f-76d1-8781-d1307fa8699d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 49, 'output_tokens': 240, 'total_tokens': 289}
# {'foo': InMemoryChatMessageHistory(messages=[HumanMessage(content='What does cosine mean?', additional_kwargs={}, response_metadata={}), AIMessage(content="In mathematics, the cosine of an angle is a trigonometric function that describes the ratio of the length of the adjacent side to the length of the hypotenuse in a right-angled triangle.\n\nTo break it down:\n\n* The adjacent side is the side next to the angle you're interested in.\n* The hypotenuse is the longest side of the triangle, opposite the right angle (90-degree angle).\n\nThe cosine of an angle (usually denoted as cos(θ)) is calculated as:\n\ncos(θ) = adjacent side / hypotenuse\n\nFor example, if you have a right-angled triangle with an angle θ, and the adjacent side is 3 units long and the hypotenuse is 5 units long, the cosine of θ would be:\n\ncos(θ) = 3 / 5 = 0.6\n\nThe cosine function is often used in various mathematical and real-world applications, such as:\n\n* Navigation and surveying\n* Physics and engineering\n* Computer graphics and game development\n* Signal processing and analysis\n\nThe cosine function has a range of -1 to 1, and it's a fundamental concept in trigonometry and mathematics.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 240, 'prompt_tokens': 49, 'total_tokens': 289, 'completion_time': 0.551828135, 'completion_tokens_details': None, 'prompt_time': 0.002221162, 'prompt_tokens_details': None, 'queue_time': 0.042010083, 'total_time': 0.554049297}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58d-361f-76d1-8781-d1307fa8699d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 240, 'total_tokens': 289})])}
# content='The inverse of the cosine function is called the arccosine function, denoted as acos(x) or cos^(-1)(x).\n\nThe arccosine function returns the angle whose cosine is a given value. In other words, it "reverses" the cosine function.\n\nMathematically, the arccosine function is defined as:\n\nθ = acos(x)\n\nwhere θ is the angle whose cosine is x, and x is a value between -1 and 1 (since the cosine function has a range of -1 to 1).\n\nFor example, if you know that the cosine of an angle is 0.6, you can use the arccosine function to find the angle:\n\nθ = acos(0.6)\n\nUsing a calculator or a mathematical library, you can find that the angle θ is approximately 53.13 degrees.\n\nNote that the arccosine function returns an angle in the range of 0 to 180 degrees (or 0 to π radians), since the cosine function is periodic and has multiple angles with the same value.\n\nThe arccosine function is useful in various applications, such as:\n\n* Solving trigonometric equations\n* Finding angles in right-angled triangles\n* Calculating distances and orientations in 3D space\n* Analyzing signals and waves in physics and engineering' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 276, 'prompt_tokens': 302, 'total_tokens': 578, 'completion_time': 0.673008817, 'completion_tokens_details': None, 'prompt_time': 0.062820955, 'prompt_tokens_details': None, 'queue_time': 0.26650057, 'total_time': 0.735829772}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4f6d808339', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019da58d-39b7-7282-9760-8e67c929c1d3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 302, 'output_tokens': 276, 'total_tokens': 578}
# {'foo': InMemoryChatMessageHistory(messages=[HumanMessage(content='What does cosine mean?', additional_kwargs={}, response_metadata={}), AIMessage(content="In mathematics, the cosine of an angle is a trigonometric function that describes the ratio of the length of the adjacent side to the length of the hypotenuse in a right-angled triangle.\n\nTo break it down:\n\n* The adjacent side is the side next to the angle you're interested in.\n* The hypotenuse is the longest side of the triangle, opposite the right angle (90-degree angle).\n\nThe cosine of an angle (usually denoted as cos(θ)) is calculated as:\n\ncos(θ) = adjacent side / hypotenuse\n\nFor example, if you have a right-angled triangle with an angle θ, and the adjacent side is 3 units long and the hypotenuse is 5 units long, the cosine of θ would be:\n\ncos(θ) = 3 / 5 = 0.6\n\nThe cosine function is often used in various mathematical and real-world applications, such as:\n\n* Navigation and surveying\n* Physics and engineering\n* Computer graphics and game development\n* Signal processing and analysis\n\nThe cosine function has a range of -1 to 1, and it's a fundamental concept in trigonometry and mathematics.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 240, 'prompt_tokens': 49, 'total_tokens': 289, 'completion_time': 0.551828135, 'completion_tokens_details': None, 'prompt_time': 0.002221162, 'prompt_tokens_details': None, 'queue_time': 0.042010083, 'total_time': 0.554049297}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58d-361f-76d1-8781-d1307fa8699d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 240, 'total_tokens': 289}), HumanMessage(content="What's its inverse", additional_kwargs={}, response_metadata={}), AIMessage(content='The inverse of the cosine function is called the arccosine function, denoted as acos(x) or cos^(-1)(x).\n\nThe arccosine function returns the angle whose cosine is a given value. In other words, it "reverses" the cosine function.\n\nMathematically, the arccosine function is defined as:\n\nθ = acos(x)\n\nwhere θ is the angle whose cosine is x, and x is a value between -1 and 1 (since the cosine function has a range of -1 to 1).\n\nFor example, if you know that the cosine of an angle is 0.6, you can use the arccosine function to find the angle:\n\nθ = acos(0.6)\n\nUsing a calculator or a mathematical library, you can find that the angle θ is approximately 53.13 degrees.\n\nNote that the arccosine function returns an angle in the range of 0 to 180 degrees (or 0 to π radians), since the cosine function is periodic and has multiple angles with the same value.\n\nThe arccosine function is useful in various applications, such as:\n\n* Solving trigonometric equations\n* Finding angles in right-angled triangles\n* Calculating distances and orientations in 3D space\n* Analyzing signals and waves in physics and engineering', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 276, 'prompt_tokens': 302, 'total_tokens': 578, 'completion_time': 0.673008817, 'completion_tokens_details': None, 'prompt_time': 0.062820955, 'prompt_tokens_details': None, 'queue_time': 0.26650057, 'total_time': 0.735829772}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4f6d808339', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da58d-39b7-7282-9760-8e67c929c1d3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 302, 'output_tokens': 276, 'total_tokens': 578})])}
